# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import math

# %%
def showImg(img, colored=False, showAxis=False):
    plt.figure(figsize=(20,20))
    if not showAxis:
        plt.axis("off")
    if (len(img.shape) == 3):
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    elif(colored):
        plt.imshow(img)
    else:
        plt.imshow(img, 'gray')

# %%
img=cv2.imread('./data/calibr1.jpg')
showImg(img)
